# %%
import polars as pl
pl.read_parquet('../data/inference/test_inference.parquet')
# Out:
# shape: (688_128, 4)
# ┌─────────────────────────────────┬────────┬──────┬──────────┐
# │ read_name                       ┆ strand ┆ pos  ┆ prob     │
# │ ---                             ┆ ---    ┆ ---  ┆ ---      │
# │ str                             ┆ str    ┆ i64  ┆ f32      │
# ╞═════════════════════════════════╪════════╪══════╪══════════╡
# │ m64168_200820_000733/2274/ccs   ┆ fwd    ┆ 2757 ┆ 0.475526 │
# │ m64168_200820_000733/2274/ccs   ┆ rev    ┆ 2757 ┆ 0.210006 │
# │ m64168_200823_191315/1704628/c… ┆ fwd    ┆ 9046 ┆ 0.951678 │
# │ m64168_200823_191315/1704628/c… ┆ rev    ┆ 9046 ┆ 0.121635 │
# │ m64168_200820_000733/460429/cc… ┆ fwd    ┆ 4575 ┆ 0.469554 │
# │ …                               ┆ …      ┆ …    ┆ …        │
# │ m64168_200820_000733/525987/cc… ┆ rev    ┆ 5956 ┆ 0.090585 │
# │ m64168_200823_191315/723298/cc… ┆ fwd    ┆ 2108 ┆ 0.524595 │
# │ m64168_200823_191315/723298/cc… ┆ rev    ┆ 2108 ┆ 0.971887 │
# │ m64168_200820_000733/723797/cc… ┆ fwd    ┆ 2269 ┆ 0.022574 │
# ...
