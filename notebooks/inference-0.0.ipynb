# %%
import polars as pl
df = pl.read_parquet('../data/inference_old/test_inference.parquet')

# %%
pl.read_parquet('../data/01_processed/train_sets/pacbio_standard_test.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pl.read_parquet('../data/01_processed/train_sets/pacbio_standard_test.parquet')
#
# File ~/miniforge3/envs/methyl-jepa/lib/python3.12/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File ~/miniforge3/envs/methyl-jepa/lib/python3.12/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
# ...

# %%
pl.read_parquet('../results/hello_world_inference.parquet')
# Out:
# shape: (1_057_792, 4)
# ┌─────────────────────────────────┬────────┬──────┬──────────┐
# │ read_name                       ┆ strand ┆ pos  ┆ prob     │
# │ ---                             ┆ ---    ┆ ---  ┆ ---      │
# │ str                             ┆ str    ┆ i64  ┆ f32      │
# ╞═════════════════════════════════╪════════╪══════╪══════════╡
# │ m64168_200823_191315/78053961/… ┆ fwd    ┆ 3630 ┆ 0.511942 │
# │ m64168_200823_191315/78053961/… ┆ rev    ┆ 3630 ┆ 0.508475 │
# │ m64168_200823_191315/151587048… ┆ fwd    ┆ 5646 ┆ 0.510652 │
# │ m64168_200823_191315/151587048… ┆ rev    ┆ 5646 ┆ 0.514761 │
# │ m64168_200823_191315/139657571… ┆ fwd    ┆ 4396 ┆ 0.515145 │
# │ …                               ┆ …      ┆ …    ┆ …        │
# │ m64168_200820_000733/9111154/c… ┆ rev    ┆ 6807 ┆ 0.511473 │
# │ m64168_200820_000733/31589497/… ┆ fwd    ┆ 2459 ┆ 0.509288 │
# │ m64168_200820_000733/31589497/… ┆ rev    ┆ 2459 ┆ 0.513337 │
# │ m64168_200823_191315/124651596… ┆ fwd    ┆ 7006 ┆ 0.51211  │
# ...
