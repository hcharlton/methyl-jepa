# %%
import polars as pl

# %%
q = (
    pl.scan_parquet('../data/01_processed/inference_sets/testset_inference_dataset.parquet')
    .select(pl.median('np'))
)
q.collect()
# Out:
# shape: (1, 1)
# ┌──────┐
# │ np   │
# │ ---  │
# │ f64  │
# ╞══════╡
# │ 13.0 │
# └──────┘

# %%
q = (
    pl.scan_parquet('../data/01_processed/inference_sets/da1.parquet')
    .select(pl.median('np'))
)
q.collect()
# Out:
# shape: (1, 1)
# ┌─────┐
# │ np  │
# │ --- │
# │ f64 │
# ╞═════╡
# │ 9.0 │
# └─────┘

# %%
q = (
    pl.scan_parquet('../data/01_processed/inference_sets/martin.parquet')
    .select(pl.median('np'))
)
q.collect()
# Out:
# shape: (1, 1)
# ┌─────┐
# │ np  │
# │ --- │
# │ f64 │
# ╞═════╡
# │ 9.0 │
# └─────┘

# %%
q = (
    pl.scan_parquet('../results/testset_inference_debug.parquet')
    .head()
)
q.collect()
# Out:
# shape: (5, 4)
# ┌─────────────────────────────┬────────┬──────┬──────────┐
# │ read_name                   ┆ strand ┆ pos  ┆ prob     │
# │ ---                         ┆ ---    ┆ ---  ┆ ---      │
# │ str                         ┆ str    ┆ i64  ┆ f32      │
# ╞═════════════════════════════╪════════╪══════╪══════════╡
# │ m64168_200823_191315/30/ccs ┆ fwd    ┆ 15   ┆ 0.933651 │
# │ m64168_200823_191315/30/ccs ┆ rev    ┆ 15   ┆ 0.590588 │
# │ m64168_200823_191315/30/ccs ┆ fwd    ┆ 493  ┆ 0.895769 │
# │ m64168_200823_191315/30/ccs ┆ rev    ┆ 493  ┆ 0.584172 │
# │ m64168_200823_191315/30/ccs ┆ fwd    ┆ 1164 ┆ 0.915619 │
# └─────────────────────────────┴────────┴──────┴──────────┘
